# %%
import pandas as pd

# %%
df=pd.read_csv("../1_data/1_raw/layoffs.csv")
df
# Out:
#             company          location  total_laid_off       date  \
# 0             Block       SF Bay Area          4000.0  2/26/2026
# 1              eBay       SF Bay Area           800.0  2/26/2026
# 2             C3.ai       SF Bay Area           280.0  2/25/2026
# 3          WiseTech  Sydney, Non-U.S.          2000.0  2/24/2026
# 4           TrueCar       Los Angeles           100.0  2/24/2026
# ...             ...               ...             ...        ...
# 4300        Service       Los Angeles             NaN  3/16/2020
# 4301   HopSkipDrive       Los Angeles             8.0  3/13/2020
# 4302    Panda Squad       SF Bay Area             6.0  3/13/2020
# 4303  Tamara Mellon       Los Angeles            20.0  3/12/2020
# 4304       EasyPost    Salt Lake City            75.0  3/11/2020
#
#       percentage_laid_off        industry  \
# 0                    0.40         Finance
# 1                    0.06          Retail
# 2                    0.26              AI
# ...

# %%
df.head()
# Out:
#     company          location  total_laid_off       date  percentage_laid_off  \
# 0     Block       SF Bay Area          4000.0  2/26/2026                 0.40
# 1      eBay       SF Bay Area           800.0  2/26/2026                 0.06
# 2     C3.ai       SF Bay Area           280.0  2/25/2026                 0.26
# 3  WiseTech  Sydney, Non-U.S.          2000.0  2/24/2026                 0.30
# 4   TrueCar       Los Angeles           100.0  2/24/2026                 0.30
#
#          industry                                             source  \
# 0         Finance  https://www.cnbc.com/2026/02/26/block-laying-o...
# 1          Retail  https://www.cnbc.com/2026/02/26/ebay-layoffs-8...
# 2              AI  https://www.morningstar.com/stocks/xnys/ai/ear...
# 3       Logistics  https://www.bloomberg.com/news/articles/2026-0...
# 4  Transportation  https://aimgroup.com/2026/02/24/truecar-cuts-3...
#
#       stage  funds_raised        country date_added
# ...

# %%
df.shape
# Out:
# (4305, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4305 entries, 0 to 4304
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   company              4305 non-null   object
#  1   location             4304 non-null   object
#  2   total_laid_off       2822 non-null   float64
#  3   date                 4305 non-null   object
#  4   percentage_laid_off  2715 non-null   float64
#  5   industry             4303 non-null   object
#  6   source               4302 non-null   object
#  7   stage                4300 non-null   object
#  8   funds_raised         3818 non-null   float64
#  9   country              4303 non-null   object
#  10  date_added           4305 non-null   object
# dtypes: float64(3), object(8)
# memory usage: 370.1+ KB

# %%
df.describe()
# Out:
#        total_laid_off  percentage_laid_off   funds_raised
# count     2822.000000          2715.000000    3818.000000
# mean       297.017364             0.293524     838.318935
# std       1042.423856             0.303418    4558.268383
# min          3.000000             0.000000       0.700000
# 25%         40.000000             0.100000      54.000000
# 50%         90.000000             0.170000     173.000000
# 75%        200.000000             0.330000     481.000000
# max      22000.000000             1.000000  121900.000000

# %%
df.isnull().sum()
# Out:
# company                   0
# location                  1
# total_laid_off         1483
# date                      0
# percentage_laid_off    1590
# industry                  2
# source                    3
# stage                     5
# funds_raised            487
# country                   2
# date_added                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
